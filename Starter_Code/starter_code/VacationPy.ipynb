# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests


# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  whitehorse  60.7161 -135.0538     10.57        62          75
# 1        1     talnakh  69.4865   88.3972      1.23        89         100
# 2        2    hermanus -34.4187   19.2345     15.56        79          97
# 3        3   adamstown -25.0660 -130.1015     21.40        69          85
# 4        4     emerald -23.5333  148.1667     26.30        49           0
#
#    Wind Speed Country        Date
# 0        8.23      CA  1697326185
# 1        2.38      RU  1697326198
# 2        9.12      ZA  1697326198
# 3        0.58      PN  1697326182
# 4        2.60      AU  1697326198

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
humidCityPlot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 2000,
)

# Display the map
# YOUR CODE HERE
humidCityPlot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
idealWeather = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                       & (city_data_df["Max Temp"] > 21) 
                                       & (city_data_df["Cloudiness"] < 3)
                                       & (city_data_df["Wind Speed"] < 4.5)
                                      ]

# Drop any rows with null values
# YOUR CODE HERE
idealWeather.dropna()

# Display sample data
# YOUR CODE HERE
idealWeather
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 4          4         emerald -23.5333  148.1667     26.30        49
# 42        42          chakia  26.4167   85.0500     21.57        69
# 68        68          turbat  26.0023   63.0440     25.60        85
# 80        80          zliten  32.4674   14.5687     22.20        66
# 101      101         fortuna  40.5982 -124.1573     21.51        62
# 117      117     as sulayyil  20.4607   45.5779     26.14        23
# 120      120        ghadamis  30.1337    9.5007     22.35        21
# 162      162       gopalganj  26.4667   84.4333     21.95        67
# 236      236           ubari  26.5921   12.7805     21.81        27
# 242      242         turabah  21.2141   41.6331     22.15        26
# 268      268       taco pozo -25.6167  -63.2833     25.53        31
# 280      280          grants  35.1473 -107.8514     22.13        17
# 285      285   alice springs -23.7000  133.8833     22.75        14
# 299      299      al balyana  26.2357   32.0035     22.12        37
# 314      314            maun -19.9833   23.4167     26.98        41
# 318      318  port macquarie -31.4333  152.9167     24.38        48
# 337      337       ascension  30.2169  -90.9001     24.12        41
# 367      367           simga  21.6333   81.7000     22.24        69
# 388      388     al kharijah  25.4514   30.5464     23.02        36
# 397      397            duba  27.3513   35.6901     26.02        58
# 457      457          waddan  29.1614   16.1390     21.01        44
# 476      476           nador  35.1740   -2.9287     21.14        64
# 487      487        haiphong  20.8561  106.6822     22.95        78
# 499      499   milledgeville  33.0801  -83.2321     21.94        79
# 517      517          gebeit  21.0667   36.3167     22.57        54
# 533      533         bereeda  11.8704   51.0579     26.66        79
# 556      556       al muwayh  22.4333   41.7583     22.76        19
#
#      Cloudiness  Wind Speed Country        Date
# 4             0        2.60      AU  1697326198
# 42            0        1.71      IN  1697326203
# 68            0        2.67      PK  1697326207
# 80            0        0.90      LY  1697326208
# 101           0        3.09      US  1697326211
# 117           0        1.87      SA  1697326212
# 120           0        4.12      LY  1697326213
# 162           0        0.76      IN  1697326218
# 236           0        2.16      LY  1697326227
# 242           0        1.60      SA  1697326228
# 268           1        2.32      AR  1697325996
# 280           0        4.12      US  1697326232
# 285           0        2.06      AU  1697326233
# 299           0        1.95      EG  1697326235
# 314           0        1.03      BW  1697326236
# 318           0        2.75      AU  1697326237
# 337           0        2.57      US  1697326239
# 367           2        1.56      IN  1697326243
# 388           0        2.88      EG  1697326246
# 397           0        2.22      SA  1697326247
# 457           0        3.38      LY  1697326255
# 476           0        0.00      MA  1697326257
# 487           0        1.54      VN  1697326258
# 499           0        2.57      US  1697326124
# 517           0        1.89      SD  1697326261
# 533           2        2.92      SO  1697326263
# 556           0        3.86      SA  1697326194

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = idealWeather[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 4           emerald      AU -23.5333  148.1667        49
# 42           chakia      IN  26.4167   85.0500        69
# 68           turbat      PK  26.0023   63.0440        85
# 80           zliten      LY  32.4674   14.5687        66
# 101         fortuna      US  40.5982 -124.1573        62
# 117     as sulayyil      SA  20.4607   45.5779        23
# 120        ghadamis      LY  30.1337    9.5007        21
# 162       gopalganj      IN  26.4667   84.4333        67
# 236           ubari      LY  26.5921   12.7805        27
# 242         turabah      SA  21.2141   41.6331        26
# 268       taco pozo      AR -25.6167  -63.2833        31
# 280          grants      US  35.1473 -107.8514        17
# 285   alice springs      AU -23.7000  133.8833        14
# 299      al balyana      EG  26.2357   32.0035        37
# 314            maun      BW -19.9833   23.4167        41
# 318  port macquarie      AU -31.4333  152.9167        48
# 337       ascension      US  30.2169  -90.9001        41
# 367           simga      IN  21.6333   81.7000        69
# 388     al kharijah      EG  25.4514   30.5464        36
# 397            duba      SA  27.3513   35.6901        58
# 457          waddan      LY  29.1614   16.1390        44
# 476           nador      MA  35.1740   -2.9287        64
# 487        haiphong      VN  20.8561  106.6822        78
# 499   milledgeville      US  33.0801  -83.2321        79
# 517          gebeit      SD  21.0667   36.3167        54
# 533         bereeda      SO  11.8704   51.0579        79
# 556       al muwayh      SA  22.4333   41.7583        19

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {"categories": "accommodation.hotel",
          "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    longitude = row["Lng"]
    latitude = row["Lat"]
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# emerald - nearest hotel: Emerald Central Hotel
# chakia - nearest hotel: No hotel found
# turbat - nearest hotel: No hotel found
# zliten - nearest hotel: عمارة بلعيد صوان
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# as sulayyil - nearest hotel: No hotel found
# ghadamis - nearest hotel: فندق عين الفارس
# gopalganj - nearest hotel: KAILASH
# ubari - nearest hotel: فندق اوباري
# turabah - nearest hotel: No hotel found
# taco pozo - nearest hotel: Hospedaje El Camionero
# grants - nearest hotel: Southwest Motel
# alice springs - nearest hotel: Aurora Alice Springs
# al balyana - nearest hotel: No hotel found
# maun - nearest hotel: Center Lodge Conference Center
# port macquarie - nearest hotel: The Observatory
# ascension - nearest hotel: Cajun Country Inn
# simga - nearest hotel: No hotel found
# al kharijah - nearest hotel: Kharga Hotel
# duba - nearest hotel: No hotel found
# waddan - nearest hotel: No hotel found
# nador - nearest hotel: Hotel Lixus
# haiphong - nearest hotel: Hoàng Hải Hotel
# milledgeville - nearest hotel: Milledgeville Hotel
# gebeit - nearest hotel: No hotel found
# bereeda - nearest hotel: No hotel found
# al muwayh - nearest hotel: فندق ومطعم الموية
#                City Country      Lat       Lng  Humidity  \
# 4           emerald      AU -23.5333  148.1667        49
# 42           chakia      IN  26.4167   85.0500        69
# 68           turbat      PK  26.0023   63.0440        85
# 80           zliten      LY  32.4674   14.5687        66
# 101         fortuna      US  40.5982 -124.1573        62
# 117     as sulayyil      SA  20.4607   45.5779        23
# 120        ghadamis      LY  30.1337    9.5007        21
# 162       gopalganj      IN  26.4667   84.4333        67
# 236           ubari      LY  26.5921   12.7805        27
# 242         turabah      SA  21.2141   41.6331        26
# 268       taco pozo      AR -25.6167  -63.2833        31
# 280          grants      US  35.1473 -107.8514        17
# 285   alice springs      AU -23.7000  133.8833        14
# 299      al balyana      EG  26.2357   32.0035        37
# 314            maun      BW -19.9833   23.4167        41
# 318  port macquarie      AU -31.4333  152.9167        48
# 337       ascension      US  30.2169  -90.9001        41
# 367           simga      IN  21.6333   81.7000        69
# 388     al kharijah      EG  25.4514   30.5464        36
# 397            duba      SA  27.3513   35.6901        58
# 457          waddan      LY  29.1614   16.1390        44
# 476           nador      MA  35.1740   -2.9287        64
# 487        haiphong      VN  20.8561  106.6822        78
# 499   milledgeville      US  33.0801  -83.2321        79
# 517          gebeit      SD  21.0667   36.3167        54
# 533         bereeda      SO  11.8704   51.0579        79
# 556       al muwayh      SA  22.4333   41.7583        19
#
#                                Hotel Name
# 4                   Emerald Central Hotel
# 42                         No hotel found
# 68                         No hotel found
# 80                       عمارة بلعيد صوان
# 101  Comfort Inn & Suites Redwood Country
# 117                        No hotel found
# 120                       فندق عين الفارس
# 162                               KAILASH
# 236                           فندق اوباري
# 242                        No hotel found
# 268                Hospedaje El Camionero
# 280                       Southwest Motel
# 285                  Aurora Alice Springs
# 299                        No hotel found
# 314        Center Lodge Conference Center
# 318                       The Observatory
# 337                     Cajun Country Inn
# 367                        No hotel found
# 388                          Kharga Hotel
# 397                        No hotel found
# 457                        No hotel found
# 476                           Hotel Lixus
# 487                       Hoàng Hải Hotel
# 499                   Milledgeville Hotel
# 517                        No hotel found
# 533                        No hotel found
# 556                     فندق ومطعم الموية

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# # Configure the map plot

hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    color="City",
    size="Humidity",
    hover_cols=["Hotel Name", "Country"]
)
# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
